# %% [markdown]
# ### BERTopic topic modelling with Llama 3.1 as representational model

# %%
#imports
import torch
import transformers
from transformers import pipeline
import pandas as pd
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer
from hdbscan import HDBSCAN
from bertopic.representation import MaximalMarginalRelevance
from bertopic.representation import TextGeneration

# %%
# load data
df = pd.read_csv('./modified_case_data.csv')
abstracts = df['abstract'].tolist()

# %%
# Embedding model: stella_en_400M_v5 (MTEB Clustering Category rank 4)

# Load the DataFrame from the CSV file
embeddings = pd.read_csv('./stella_en_400M_v5.csv')

# Extract embeddings
document_ids = embeddings['ucid'].values
embeddings = embeddings.drop('ucid', axis=1).values

# %%
# Vectorizer Model
vec_model = CountVectorizer(stop_words='english', ngram_range=(1,2))

# %%
prompt = '''<|begin_of_text|><|start_header_id|>system<|end_header_id|>

            Cutting Knowledge Date: December 2023
            Today Date: 06 Aug 2024

            You are a helpful assistant who helps to create labels for topics in a topic modelling pipeline. <|eot_id|><|start_header_id|>user<|end_header_id|>
            I've a topic that contains the following documents:
            [DOCUMENTS]

The topic is described by the following keywords: '[KEYWORDS]'.

Based on the information above, extract only one short topic label in the following format:
topic: <topic label>
Output only the label and nothing else. <|eot_id|><|start_header_id|>assistant<|end_header_id|>'''

# %%
model_id = "meta-llama/Meta-Llama-3.1-8B-Instruct"

generator = transformers.pipeline(
    "text-generation", 
    model=model_id,
    model_kwargs={"torch_dtype": torch.bfloat16},
    device_map="auto",
    max_new_tokens=500,
    temperature = 0.1,
    repetition_penalty=1.1
)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Some parameters are on the meta device device because they were offloaded to the cpu.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# Create your representation model

llama = TextGeneration(generator, prompt=prompt, doc_length = 2000, tokenizer='char', diversity=0.1)

mmr = MaximalMarginalRelevance(diversity=0.3)
representation_models = [mmr, llama]

# Use the chained models
topic_model = BERTopic(representation_model=representation_models, vectorizer_model=vec_model, verbose=True, calculate_probabilities=True)

# %%
topics, probs = topic_model.fit_transform(abstracts, embeddings=embeddings)

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                                               Name  \
# 0       -1  23334      -1_\n\ntopic: Hybrid Vehicle Power Systems___
# 1        0   1355  0_\n\ntopic: Hybrid Power Transmission Systems___
# 2        1   1025          1_\n\ntopic: Vehicle Hydraulic Systems___
# 3        2    614  2_\n\ntopic: Hybrid Vehicle Emission Control S...
# 4        3    574  3_\n\ntopic: Hybrid Vehicle Drive Train System...
# ..     ...    ...                                                ...
# 419    418     10  418_\n\ntopic: Hybrid Power Systems for Engine...
# 420    419     10  419_\n\ntopic: Road Surface Gradient Estimatio...
# 421    420     10    420_\n\ntopic: Vehicle Cooling System Design___
# 422    421     10  421_\n\ntopic: Regenerative Retarder Control S...
# 423    422     10  422_\n\ntopic: Hybrid Electric Vehicle Energy ...
#
#                                         Representation  \
# 0    [\n\ntopic: Hybrid Vehicle Power Systems, , , ...
# 1    [\n\ntopic: Hybrid Power Transmission Systems,...
# 2    [\n\ntopic: Vehicle Hydraulic Systems, , , , ,...
# 3    [\n\ntopic: Hybrid Vehicle Emission Control Sy...
# 4    [\n\ntopic: Hybrid Vehicle Drive Train Systems...
# ..                                                 ...
# 419  [\n\ntopic: Hybrid Power Systems for Engineeri...
# 420  [\n\ntopic: Road Surface Gradient Estimation a...
# 421  [\n\ntopic: Vehicle Cooling System Design, , ,...
# 422  [\n\ntopic: Regenerative Retarder Control Syst...
# 423  [\n\ntopic: Hybrid Electric Vehicle Energy Man...
#
#                                    Representative_Docs
# 0    [PROBLEM TO BE SOLVED: To provide a hybrid veh...
# 1    [The invention discloses a double-planet-row d...
# 2    [To provide a vehicle hydraulic control device...
# 3    [PROBLEM TO BE SOLVED: To suppress the deterio...
# 4    [The present invention relates to a hybrid tra...
# ..                                                 ...
# 419  [The invention relates to an energy-saving hyd...
# 420  [PROBLEM TO BE SOLVED: To more properly estima...
# 421  [A vehicle that includes an electric motor (2,...
# 422  [PURPOSE:To prevent a vehicle from deteriorati...
# 423  [The invention discloses an intelligent hybrid...
#
# [424 rows x 5 columns]

# %%
print(topics)

# %%
topic_model.get_topic_info(10)
# Out:
#    Topic  Count                                               Name  \
# 0     10    288  10_\n\ntopic: Torsional Vibration Damper Techn...
#
#                                       Representation  \
# 0  [\n\ntopic: Torsional Vibration Damper Technol...
#
#                                  Representative_Docs
# 0  [Torsional vibration damper (100, 200), in par...

# %%
with open('topics_llama.txt', 'w') as f:
    # Loop over the topics and write the output to the file
    for topic in range(10):
        topic_info = topic_model.get_topic(topic)
        representative_docs = df[df.topic == topic][:10]['document'].tolist()

        f.write(f"Topic: {topic}\n")
        f.write("Topic Information: \n")
        f.write(f"{topic_info}\n")
        f.write("Representative Documents: \n")
        for doc in representative_docs:
            f.write(f"{doc}\n")
        f.write("\n")

# %%
topics_dict = topic_model.get_topics()

# %%
for k, v in topics_dict.items():
    print(k, v[0][0].strip())
# Out:
# -1 topic: Hybrid Vehicle Power Systems
# 0 topic: Hybrid Power Transmission Systems
# 1 topic: Vehicle Hydraulic Systems
# 2 topic: Hybrid Vehicle Emission Control Systems
# 3 topic: Hybrid Vehicle Drive Train Systems
# 4 topic: Hydraulic Hybrid Systems
# 5 topic: Hybrid Vehicle Cooling System Design
# 6 topic: Hybrid Vehicle Drive Control System
# 7 topic: Hybrid Vehicle Noise Reduction Control
# 8 topic: Hybrid Electric Vehicle Technology
# 9 topic: Vibration Damping Control Device
# 10 topic: Torsional Vibration Damper Technology
# 11 topic: Vehicle Transmission Systems
# 12 topic: Power Supply Systems and Control Devices
# 13 topic: Compressed Air Hybrid Vehicle Technology
# 14 topic: Fuel-Efficient Route Planning for Hybrid Vehicles
# 15 topic: Reducing Shift Shock in Vehicle Power Transmission Devices
# 16 topic: Flywheel Energy Storage Systems
# 17 topic: Regenerative Braking Control Systems
# 18 topic: Engine Start Control in Hybrid Vehicles
# 19 topic: Motor Temperature Regulation
# 20 topic: Hybrid Transmission Systems
# 21 topic: Hydrogen Fuel Cell Technology
# 22 topic: Automotive Clutches and Hybrid Modules
# 23 topic: Engine Start Control in Hybrid Vehicles
# 24 topic: Hybrid Tractor Technology
# 25 topic: Vehicle Drive Device Design
# 26 topic: Vehicle Collision Protection Systems
# 27 topic: Motor Speed and Torque Control in Hybrid Automobiles
# 28 topic: Electric Vehicle Battery Cooling Systems
# 29 topic: Battery State Estimation and Management
# 30 topic: Electric Motor Design Optimization
# 31 topic: Hybrid Vehicle Drive Systems
# 32 topic: Hybrid Power System Design
# 33 topic: Filter Regeneration Control for Particulate Matter in Internal Combustion Engines
# 34 topic: Hybrid Power Systems
# 35 topic: Energy Recovery Systems for Vehicles
# 36 topic: Hydraulic Hybrid Power Systems
# 37 topic: Electric Drive Systems for Motor Vehicles
# 38 topic: Vehicle Battery Mounting Structure
# 39 topic: Electric Vehicle Transmission Systems
# 40 topic: Hybrid Power System with Double Clutch Technology
# 41 topic: Hybrid Transmission Mode Transition Control
# 42 topic: Automatic Transmissions for Electric Vehicles
# 43 topic: Electric Supercharger Control Systems
# 44 topic: Parking Lock Mechanism Control
# 45 topic: Hybrid Vehicle Drive Systems
# 46 topic: Hybrid Construction Machines
# 47 topic: Engine Idle Stop Control Systems
# 48 topic: Hybrid Four-Wheel Drive Systems
# 49 topic: Oil-Electricity Hybrid Power Systems for Automobiles
# 50 topic: Automotive Starter Systems
# 51 topic: Hybrid Driving Device Design
# 52 topic: Hybrid Vehicle Power Transmission Systems
# 53 topic: Hybrid Motorcycles
# 54 topic: Motor Traction Control Systems for Vehicle Stability and Slip Prevention
# 55 topic: Hybrid Vehicle Air Conditioning System
# 56 topic: Hybrid Vehicle Battery Management System
# 57 topic: Hybrid Vehicle Powertrains and Turbocharged Engines
# 58 topic: Hybrid Semi-Trailer Drive Systems
# 59 topic: Hybrid Vehicle Safety Control System
# 60 topic: Hybrid Vehicle Information Display Systems
# 61 topic: Battery Cooling Systems
# 62 topic: Vehicle Cooling Systems and Temperature Regulation
# 63 topic: Torque Transmission Devices
# 64 topic: Fuel Evaporative Purge System Control
# 65 topic: Hybrid Vehicle Mode Switching Control
# 66 topic: Planetary Gearbox Design
# 67 topic: Continuously Variable Transmission Device
# 68 topic: Hybrid Vehicle Engine Starting Methods
# 69 topic: Engine Vibration Suppression During Start-Up
# 70 topic: Waste Heat Recovery Systems
# 71 topic: Power Transmission Systems for Vehicles
# 72 topic: Vehicle Clutch Control Systems
# 73 topic: Engine Misfire Identification Device
# 74 topic: Vehicle Transmissions
# 75 topic: Agricultural Vehicle Drive Systems
# 76 topic: Clutch Temperature Protection Control in Hybrid Vehicles
# 77 topic: Suppressing Rattling Noise in Power Transmission Devices
# 78 topic: Hybrid Vehicle Drive Train Control Systems
# 79 topic: Exhaust Gas Recirculation Control Systems
# 80 topic: Hybrid Vehicle Drive System Control
# 81 topic: Vehicle Yaw Rate Control and Distribution
# 82 topic: Dual Clutch Transmission Design
# 83 topic: Torque Request Distribution and Control in Vehicle Powertrains
# 84 topic: Low-Temperature Engine Starting Systems
# 85 topic: Hybrid Electric Vehicles with Super Capacitors
# 86 topic: Lithium Secondary Battery Design Improvements
# 87 topic: Hybrid Vehicle Clutch Control Systems
# 88 topic: Collision Detection System for Hybrid Vehicles
# 89 topic: Battery Temperature Control
# 90 topic: Hybrid Vehicle Power Assembly Device
# 91 topic: Engine Stopping Control Using Crank Angle Feedback
# 92 topic: Engine Fault Diagnosis and Failure Determination Systems
# 93 topic: Hybrid Vehicle Transmission Systems
# 94 topic: Reciprocating Piston Engine Technology
# 95 topic: Vehicle Control Systems for Hybrid Vehicles
# 96 topic: Wind Power Generation for Vehicles
# 97 topic: Hybrid Power Drive System
# 98 topic: Electric Vehicle Drive System Optimization
# 99 topic: Hybrid Power Systems
# 100 topic: Electric or Hybrid Vehicles
# 101 topic: Hybrid Vehicle Propulsion Systems
# 102 topic: Hybrid Powertrain Control Systems
# 103 topic: Battery Module Design
# 104 topic: Engine Start/Stop Control Systems for Hybrid Vehicles
# 105 topic: Hybrid Electric Vehicles with Compressed Air Power Systems
# 106 topic: Vehicle Creep Control Systems
# 107 topic: Electric Vehicle Charging Systems
# 108 topic: Electrically Variable Transmission Design
# 109 topic: Hybrid Powertrain Design
# 110 topic: Hybrid Vehicle Power Supply System
# 111 topic: Hybrid Vehicle Fuel Efficiency Improvement
# 112 topic: Motor Vehicle Drive Train Control Method
# 113 topic: Regenerative Braking Control Systems for Hybrid Vehicles
# 114 topic: Hybrid Drive Module Design
# 115 topic: Hybrid Vehicle Driving Force Transmission Device
# 116 topic: Idle Stop Vehicle Power Generation System
# 117 topic: Hybrid Vehicle Drive Systems
# 118 topic: Brake System Pressure Management
# 119 topic: Hybrid Power System for Heavy Dump Trucks
# 120 topic: Hybrid Electric Vehicle Power Train Design
# 121 topic: Solar Hybrid Electric Vehicles
# 122 topic: Hybrid Power Output Apparatus
# 123 topic: Clutch Control Optimization
# 124 topic: Electric Motor Control Systems
# 125 topic: Wheel Slip Control in Hybrid Vehicles
# 126 topic: Automobile Suspension Systems
# 127 topic: Crank Angle Estimation and Control in Hybrid Vehicles
# 128 topic: Power Drive Systems
# 129 topic: Motor Control for Auxiliary Machines in Vehicles
# 130 topic: Automatic Transmission Systems
# 131 topic: Vehicle Propulsion Device with Planetary Gearbox
# 132 topic: Hybrid Electric Vehicle Power Systems
# 133 topic: Overvoltage Protection in Inverter Circuits
# 134 topic: Regenerative Braking Control in Electric Vehicles
# 135 topic: Vehicle Torque Assist System
# 136 topic: Hybrid Motorcycle Propulsion Systems
# 137 topic: Hybrid Electric Heavy Truck Technology
# 138 topic: Hybrid Electric Tricycles
# 139 topic: Power Transmission Systems for Vehicles
# 140 topic: Hybrid Vehicle Transmission Systems
# 141 topic: Vehicle Drive Control Device
# 142 topic: Hybrid Vehicle Control Systems
# 143 topic: Sensorless Control for Electric Machines
# 144 topic: Vehicle Deceleration Control Systems
# 145 topic: Electric Drive Axle Assembly
# 146 topic: Fuel Cell Hybrid Electric Vehicle Emergency Operation Control Method
# 147 topic: Engine Control System Optimization
# 148 topic: Electric Vehicle Fault Detection System
# 149 topic: Vehicle Diagnosis System for Hybrid Vehicles
# 150 topic: Hybrid Power System for Automobiles
# 151 topic: Hybrid Vehicle Hydraulic System Control
# 152 topic: Improving Powder Clutch Performance in Hybrid Vehicles
# 153 topic: Power Transmission Systems for Vehicles
# 154 topic: Vehicle Acceleration Control System
# 155 topic: Hybrid Powertrain Design
# 156 topic: Electric Vehicle Transmission Systems
# 157 topic: Energy Efficiency Improvement in Power Distribution Mechanism
# 158 topic: Hybrid Vehicle Control Device
# 159 topic: Vehicle Mounting Systems
# 160 topic: Vehicle Safety Notification Systems
# 161 topic: Hybrid Vehicle Components and Systems
# 162 topic: All-Terrain Vehicle Design and Hybrid Power Systems
# 163 topic: Hybrid Vehicle Drive Device
# 164 topic: Induction Machine Braking System
# 165 topic: Hybrid Aircraft Design
# 166 topic: Electric Vehicle Conversion Kits
# 167 topic: Bus Hydraulic Hybrid Power Drive Device
# 168 topic: Internal Combustion Engine Start Control Systems
# 169 topic: Hybrid Vehicle Powertrain Systems
# 170 topic: Automatic Transmission System Design
# 171 topic: Hybrid Work Vehicle Design
# 172 topic: Hybrid Power System for Cranes
# 173 topic: Power Transmission System Design
# 174 topic: Power-Driven System Design
# 175 topic: Engine Timing Control Mechanism
# 176 topic: Vehicle Launch Control System
# 177 topic: Hybrid Vehicle Transmission Systems
# 178 topic: Hybrid Vehicle Transmissions
# 179 topic: Automatic Transmission System Design
# 180 topic: Electric Tractor Power Transmission Systems
# 181 topic: Electric Motor Design for Hybrid Saddle Vehicles
# 182 topic: Torsional Vibration Dampening Systems
# 183 topic: Electric Hybrid Buses
# 184 topic: Clutch Fault Diagnosis
# 185 topic: Vehicle Refueling Optimization Systems
# 186 topic: Hybrid Automatic Transmission (H-AMT) System
# 187 topic: Engine Start Control Systems
# 188 topic: Electric Vehicle Range Extenders
# 189 topic: Power Conversion Systems for Railways
# 190 topic: Vehicle Energy Efficiency Improvement Using Motor Generator Control
# 191 topic: Continuously Variable Transmission Control System
# 192 topic: Hybrid Power Plants and Mechanical Engineering Innovations
# 193 topic: Engine Start Control Device
# 194 topic: Vehicle Transmission Control Systems
# 195 topic: Hybrid Electric Drive System
# 196 topic: Electric Motor Design and Shielding
# 197 topic: Hybrid Vehicle Driveline Disconnect Clutch Operation
# 198 topic: Limp Home Control System for Hybrid Vehicles
# 199 topic: Multistage Transmission Design
# 200 topic: Hybrid Power Drive System
# 201 topic: Valve Control Systems
# 202 topic: Automotive Powertrain Design
# 203 topic: Vehicle Clutch Control System
# 204 topic: Hybrid Power Systems with Planetary Gears for Stepless Speed Change
# 205 topic: Hybrid Powertrain Starting Systems
# 206 topic: Vehicle Acceleration Performance Improvement Using Fluid Coupling and Motor Generators
# 207 topic: Powertrain System Control
# 208 topic: Fuel Injection Valve Maintenance and Optimization
# 209 topic: Hybrid Vehicle Shift Control System
# 210 topic: Hybrid Work Vehicle Control Systems
# 211 topic: Vehicle Battery Warming Systems
# 212 topic: Electric Vehicle Design
# 213 topic: Steam Power Generation Systems
# 214 topic: Hybrid Power Systems with Flywheel Energy Storage
# 215 topic: Automatic Engagement Mechanisms
# 216 topic: Couplings for Rotating Electrical Machines in Automotive Industry
# 217 topic: Vehicle Power Drive System Design
# 218 topic: Dog Clutch Engagement Mechanism
# 219 topic: Engine Start Control and Shock Suppression
# 220 topic: Hybrid Power Systems for Loaders
# 221 topic: Hybrid Power Plant Design
# 222 topic: Hybrid Electric Vehicle Power System Control
# 223 topic: Wireless Power Transmission Systems
# 224 topic: Torque Measurement Devices
# 225 topic: Hybrid Electric Drive System
# 226 topic: Vehicle Speed Limit Control System
# 227 topic: Hybrid Power Sanitation Cart Systems
# 228 topic: Road Sweeping Vehicles
# 229 topic: Single Motor Hybrid Power Speed Changer Design
# 230 topic: Range Extended Electric Vehicle Power System
# 231 topic: Agricultural Machinery Design
# 232 topic: Engine Control Systems for Hybrid Vehicles
# 233 topic: Automatic Transmission Design
# 234 topic: Torque Vectoring Device for High-Performance Vehicles
# 235 topic: Four-Wheel Drive Vehicle Control Systems
# 236 topic: Transmission Warm-Up Control Systems
# 237 topic: Lawn Mowers
# 238 topic: Improving Drivability through Adaptive Learning Control in Vehicle Transmissions
# 239 topic: Hybrid Vehicle Design and Weight Balance
# 240 topic: Hybrid Vehicle Safety Features
# 241 topic: Vehicle Control Device Failure Detection
# 242 topic: Hybrid Forklift Technology
# 243 topic: Hybrid Vehicle Power Management System
# 244 topic: Fire Engine Chassis Design
# 245 topic: Power Driving System Design
# 246 topic: Electric Vehicle Control Systems
# 247 topic: Vehicle Power Transmission Control Systems
# 248 topic: Flywheel Regeneration System
# 249 topic: Hybrid Drive Transmission System Design
# 250 topic: Electric Power Generation Systems
# 251 topic: Electric Machine Cooling Systems
# 252 topic: Vehicle Transmission Systems
# 253 topic: Hybrid Vehicle Engine Stopping Control
# 254 topic: Vehicle Travel Distance Estimation
# 255 topic: Tracked Vehicle Transmission Systems
# 256 topic: Hybrid Powertrain Design
# 257 topic: Fuel Efficiency Optimization in Hybrid Vehicles Using Mixed Fuels
# 258 topic: Four-Wheel Drive Vehicle Control Systems
# 259 topic: Hybrid Vehicle Temperature Control Systems
# 260 topic: Hybrid Concrete Mixer Truck Technology
# 261 topic: Preventing Belt Slip in Vehicle Generators
# 262 topic: Vibration Reduction in Electric Vehicle Drive Devices
# 263 topic: Motor Vehicle Transmission Design
# 264 topic: Engine Starter Systems
# 265 topic: Hybrid Power Pack Design
# 266 topic: Electric Vehicle Motor Cooling Structure
# 267 topic: Hybrid Marine Propulsion Systems
# 268 topic: Vehicle Abnormality Detection and Control Systems
# 269 topic: Multi-Mode Power Transmission Systems
# 270 topic: Amphibious Vehicle Transmission Systems
# 271 topic: Multistage Transmission Design
# 272 topic: Hybrid Electric Dump Truck Technology
# 273 topic: Hybrid Electric Vehicle Motor Technology
# 274 topic: Drive Device for Work Machine
# 275 topic: Temperature Sensor Failure Detection in Hybrid Vehicles
# 276 topic: Hybrid Power System with Dual Rotor Motors
# 277 topic: Hybrid Power System Design
# 278 topic: Hybrid Concrete Pump Technology
# 279 topic: Electric Vehicle Charging Control System
# 280 topic: Power Transmission Apparatus Design
# 281 topic: Atmospheric Pressure Compensation in Hybrid Vehicles
# 282 topic: Electric Vehicle Traction Architecture
# 283 topic: Transmission Arrangement Design
# 284 topic: Infinitely Variable Transmission Systems
# 285 topic: Electric Vehicle Powertrain Optimization
# 286 topic: Hybrid Vehicle Control Systems
# 287 topic: Hybrid Transmission Systems
# 288 topic: Electrically Variable Transmission Systems
# 289 topic: Hybrid Electric Vehicle Technology
# 290 topic: Range Extender Motor Assembly Design
# 291 topic: Hydraulic Clutch Pressure Control in Electro-Mechanical Transmissions
# 292 topic: Pump Drive Unit Operation
# 293 topic: Extended Range Electric Automobile Systems
# 294 topic: Selectable One-Way Clutch Design
# 295 topic: Mechanical Transmission System Design
# 296 topic: Accessory Drive System for Hybrid Electric Vehicles
# 297 topic: Vehicle Battery Control System
# 298 topic: Hybrid Vehicle Drive Device Design Optimization
# 299 topic: Hybrid Vehicle Transmission Components
# 300 topic: Planetary Gear Multi-Speed Transmission Design
# 301 topic: Hybrid Vehicle Transmission Systems
# 302 topic: Torque Transmission Device Design
# 303 topic: Automobile Hybrid Transmission System
# 304 topic: Drive Train Control Systems
# 305 topic: Hybrid Vehicle Power Train Efficiency
# 306 topic: Electric Power Unit Design Optimization
# 307 topic: Hybrid Electric Vehicle Belt Pulley Systems
# 308 topic: Rear-Wheel Drive System with Hydraulic Brakes and Electric Motors
# 309 topic: Electric Vehicle Rear Structure Optimization
# 310 topic: Reducing Hybrid Vehicle Component Size and Improving Mountability
# 311 topic: Distributed Control Module System Integrity Monitoring
# 312 topic: Vehicle Drive Device Cooling Systems
# 313 topic: Smooth Gear Shifting Control for Power Storage Device Protection
# 314 topic: Hybrid Vehicle Power Systems
# 315 topic: Hybrid Powertrain Control Methods
# 316 topic: Hybrid Vehicle Mode Switching Control System
# 317 topic: Power Take-Off (PTO) Systems and Mechanisms
# 318 topic: Clutch Torque Adaption Methods for Hybrid Vehicles
# 319 topic: Multi-Speed Planetary Gearbox Design
# 320 topic: Internal Combustion Engine Starting Control Systems
# 321 topic: Bimotor Hybrid Vehicle Drive Systems
# 322 topic: Hybrid Vehicle Mode Control
# 323 topic: Engine Start Control Device for Vehicle
# 324 topic: Electric Machine Integration in Internal Combustion Engines
# 325 topic: Electric Power Conversion Device Design
# 326 topic: Hybrid Vehicle Design
# 327 topic: Regenerative Control Method for Automobiles with High Pressure Accumulator
# 328 topic: Hybrid Vehicle Drive Systems
# 329 topic: Hybrid Vehicle Powertrain Design
# 330 topic: Vehicle Gearbox Design
# 331 topic: Planetary Gear Transmission Design
# 332 topic: Automatic Transmission Design
# 333 topic: Vehicle Drive Control Systems
# 334 topic: Electric Vehicle Charging Infrastructure Management
# 335 topic: Automatic Transmission System Design
# 336 topic: Hybrid Electric Vehicle Powertrains
# 337 topic: Electric Vehicle Axle Systems
# 338 topic: Hybrid Electric Vehicle Energy Storage System
# 339 topic: Electric Golf Cart Design and Optimization
# 340 topic: Automatic Transmissions for Motor Vehicles
# 341 topic: Hybrid Electric Internal Combustion Engine Systems
# 342 topic: Engine Control Device for Range Extender
# 343 topic: Hydraulic Energy Storage Systems
# 344 topic: Electric Vehicle Propulsion Systems
# 345 topic: Hybrid Vehicle Battery Management Systems
# 346 topic: Vehicle Control Software Management
# 347 topic: Manual Transmission Design for Hybrid Vehicles
# 348 topic: Optimizing Starter Motor Performance in Plug-In Hybrid Vehicles
# 349 topic: Hybrid Vehicle Combustion Mode Switching Control
# 350 topic: Variable Compression Ratio Control in Internal Combustion Engines
# 351 topic: Hybrid Vehicle Transmission Systems
# 352 topic: Battery Management System for Hybrid Vehicles
# 353 topic: Hybrid Vehicle Power Transmission System
# 354 topic: Hybrid Vehicle Engine Assistance Systems
# 355 topic: Hybrid Vehicle Power System
# 356 topic: Electro-Mechanical Transmission Control Systems
# 357 topic: Hybrid Electric Vehicle Engine Systems
# 358 topic: Automated Manual Transmission Gearshifting Systems
# 359 topic: Hybrid Electric Vehicle Chassis Design
# 360 topic: Hybrid Vehicle Fuel Efficiency Improvement During Deceleration
# 361 topic: Electric Vehicle Battery Management System
# 362 topic: Double-Motor Hybrid Power Transmission Systems
# 363 topic: Hybrid Vehicle Fuel Efficiency Improvement
# 364 topic: Gas-Electricity Hybrid Power Systems for Vehicles
# 365 topic: Continuously Variable Transmission Systems
# 366 topic: Hybrid Vehicle Clutch Control Systems
# 367 topic: Vehicle Motor Drive Assembly Design
# 368 topic: Electric Vehicle Technology
# 369 topic: Electric Motor Connection Control in Vehicle Power Transmission Systems
# 370 topic: Hybrid Car Energy Cost Display Device
# 371 topic: Hybrid Electric Vehicle Powertrain Systems
# 372 topic: Hybrid Electric Drive Systems
# 373 topic: Mechanical Engineering
# 374 topic: Vehicle Drive Device Control Systems
# 375 topic: Hybrid Vehicle Fuel Efficiency Control
# 376 topic: Exhaust Aftertreatment Systems in Hybrid Vehicles
# 377 topic: Engine Start-Up Optimization Techniques
# 378 topic: Hybrid Vehicle Energy Efficiency Control
# 379 topic: Vehicle Shift Control Systems
# 380 topic: Electric Vehicle Power Transmission Systems
# 381 topic: Vehicle Powertrain Design
# 382 topic: Automatic Transmission Design
# 383 topic: Hybrid Electric Vehicle Power Systems
# 384 topic: Fuel Tank Arrangement Optimization for Vehicle Cabin Space Expansion
# 385 topic: Electric Vehicle Power System
# 386 topic: Underground Ore Deposit Transportation Vehicle
# 387 topic: Accessory Driving Systems
# 388 topic: Hybrid Powertrain Systems
# 389 topic: Hybrid Electric Vehicle Energy Management
# 390 topic: Hybrid Vehicle Drive Device Design
# 391 topic: Hybrid Vehicle Drive Control System
# 392 topic: Downhill Road Vehicle Speed Control System
# 393 topic: Power Transmission Devices
# 394 topic: Electric Vehicle Transmission Components
# 395 topic: Electric Vehicle Regeneration Control Systems
# 396 topic: Hybrid Vehicle Power Control Apparatus
# 397 topic: Regenerative Braking Systems in Hybrid Vehicles
# 398 topic: Hybrid Vehicle Powertrain Design
# 399 topic: Vehicular Power Transmission Control Systems
# 400 topic: Power Electronics for Electrical Machines
# 401 topic: Hybrid Vehicle Transmission Systems
# 402 topic: Power Drive System
# 403 topic: Powertrain System Control and Optimization
# 404 topic: Hybrid Vehicle Torque Converter Design
# 405 topic: Hybrid Locomotive Technology
# 406 topic: Electric Vehicle Drive Devices and Machines
# 407 topic: Vehicle Charging Equipment Installation Structure
# 408 topic: Electric Motor Systems
# 409 topic: Regenerative Downshift Control in Manual Transmission Systems
# 410 topic: Speed Reduction Mechanism for Motor Rotational Force Transmission Device
# 411 topic: Hybrid Vehicle Transmission Control Systems
# 412 topic: Power Plant for Vehicle
# 413 topic: Automotive Drive Systems
# 414 topic: Idling Control Systems for Hybrid Vehicles
# 415 topic: Optimizing Engine and Motor Control for Efficient Power Energy Recovery
# 416 topic: Electric Vehicle Battery Management Systems
# 417 topic: Hybrid Electric Vehicle Energy Management Systems
# 418 topic: Hybrid Power Systems for Engineering Machinery
# 419 topic: Road Surface Gradient Estimation and Control
# 420 topic: Vehicle Cooling System Design
# 421 topic: Regenerative Retarder Control Systems for Fuel Efficiency and Emissions Reduction
# 422 topic: Hybrid Electric Vehicle Energy Management

# %%
# Reduce outliers using the `probabilities` strategy
topic_model.reduce_outliers(abstracts, topics, probabilities=probs, strategy="probabilities")
# Out:
# []

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                                               Name  \
# 0       -1  23334      -1_\n\ntopic: Hybrid Vehicle Power Systems___
# 1        0   1355  0_\n\ntopic: Hybrid Power Transmission Systems___
# 2        1   1025          1_\n\ntopic: Vehicle Hydraulic Systems___
# 3        2    614  2_\n\ntopic: Hybrid Vehicle Emission Control S...
# 4        3    574  3_\n\ntopic: Hybrid Vehicle Drive Train System...
# ..     ...    ...                                                ...
# 419    418     10  418_\n\ntopic: Hybrid Power Systems for Engine...
# 420    419     10  419_\n\ntopic: Road Surface Gradient Estimatio...
# 421    420     10    420_\n\ntopic: Vehicle Cooling System Design___
# 422    421     10  421_\n\ntopic: Regenerative Retarder Control S...
# 423    422     10  422_\n\ntopic: Hybrid Electric Vehicle Energy ...
#
#                                         Representation  \
# 0    [\n\ntopic: Hybrid Vehicle Power Systems, , , ...
# 1    [\n\ntopic: Hybrid Power Transmission Systems,...
# 2    [\n\ntopic: Vehicle Hydraulic Systems, , , , ,...
# 3    [\n\ntopic: Hybrid Vehicle Emission Control Sy...
# 4    [\n\ntopic: Hybrid Vehicle Drive Train Systems...
# ..                                                 ...
# 419  [\n\ntopic: Hybrid Power Systems for Engineeri...
# 420  [\n\ntopic: Road Surface Gradient Estimation a...
# 421  [\n\ntopic: Vehicle Cooling System Design, , ,...
# 422  [\n\ntopic: Regenerative Retarder Control Syst...
# 423  [\n\ntopic: Hybrid Electric Vehicle Energy Man...
#
#                                    Representative_Docs
# 0    [PROBLEM TO BE SOLVED: To provide a hybrid veh...
# 1    [The invention discloses a double-planet-row d...
# 2    [To provide a vehicle hydraulic control device...
# 3    [PROBLEM TO BE SOLVED: To suppress the deterio...
# 4    [The present invention relates to a hybrid tra...
# ..                                                 ...
# 419  [The invention relates to an energy-saving hyd...
# 420  [PROBLEM TO BE SOLVED: To more properly estima...
# 421  [A vehicle that includes an electric motor (2,...
# 422  [PURPOSE:To prevent a vehicle from deteriorati...
# 423  [The invention discloses an intelligent hybrid...
#
# [424 rows x 5 columns]

# %%
topic_model.get_document_info(abstracts)
# Out:
#                                                 Document  Topic  \
# 0      A hydraulic regenerative braking and power sup...     -1
# 1      Higher, the lower planet row plug-in hybrid-po...      0
# 2      The traction arrangement comprises one or more...     -1
# 3      A dual-motor hybrid power driving system compr...    362
# 4      FIELD: transport.SUBSTANCE: hybrid transmissio...     20
# ...                                                  ...    ...
# 46661  A battery arrangement for a motor vehicle incl...     12
# 46662  The invention relates to a method for operatin...     58
# 46663  A torsional vibration damping system (7) for a...     10
# 46664  Various methods and systems are provided for a...     42
# 46665  A method is provided for scheduling regenerati...     -1
#
#                                                     Name  \
# 0          -1_\n\ntopic: Hybrid Vehicle Power Systems___
# 1      0_\n\ntopic: Hybrid Power Transmission Systems___
# 2          -1_\n\ntopic: Hybrid Vehicle Power Systems___
# 3      362_\n\ntopic: Double-Motor Hybrid Power Trans...
# 4           20_\n\ntopic: Hybrid Transmission Systems___
# ...                                                  ...
# 46661  12_\n\ntopic: Power Supply Systems and Control...
# 46662  58_\n\ntopic: Hybrid Semi-Trailer Drive System...
# 46663  10_\n\ntopic: Torsional Vibration Damper Techn...
# 46664  42_\n\ntopic: Automatic Transmissions for Elec...
# 46665      -1_\n\ntopic: Hybrid Vehicle Power Systems___
#
#                                           Representation  \
# 0      [\n\ntopic: Hybrid Vehicle Power Systems, , , ...
# 1      [\n\ntopic: Hybrid Power Transmission Systems,...
# 2      [\n\ntopic: Hybrid Vehicle Power Systems, , , ...
# 3      [\n\ntopic: Double-Motor Hybrid Power Transmis...
# 4      [\n\ntopic: Hybrid Transmission Systems, , , ,...
# ...                                                  ...
# 46661  [\n\ntopic: Power Supply Systems and Control D...
# 46662  [\n\ntopic: Hybrid Semi-Trailer Drive Systems,...
# 46663  [\n\ntopic: Torsional Vibration Damper Technol...
# 46664  [\n\ntopic: Automatic Transmissions for Electr...
# 46665  [\n\ntopic: Hybrid Vehicle Power Systems, , , ...
#
#                                      Representative_Docs  \
# 0      [PROBLEM TO BE SOLVED: To provide a hybrid veh...
# 1      [The invention discloses a double-planet-row d...
# 2      [PROBLEM TO BE SOLVED: To provide a hybrid veh...
# 3      [A double-motor hybrid power driving system co...
# 4      [Hybrid transmission device with a first trans...
# ...                                                  ...
# 46661  [The in-vehicle controller of the present disc...
# 46662  [PROBLEM TO BE SOLVED: To effectively improve ...
# 46663  [Torsional vibration damper (100, 200), in par...
# 46664  [Transmission (1) for a vehicle (100), compris...
# 46665  [PROBLEM TO BE SOLVED: To provide a hybrid veh...
#
#                                              Top_n_words  Probability  \
# 0      \n\ntopic: Hybrid Vehicle Power Systems -  -  ...     0.486581
# 1      \n\ntopic: Hybrid Power Transmission Systems -...     0.195589
# 2      \n\ntopic: Hybrid Vehicle Power Systems -  -  ...     0.902328
# 3      \n\ntopic: Double-Motor Hybrid Power Transmiss...     1.000000
# 4      \n\ntopic: Hybrid Transmission Systems -  -  -...     0.199330
# ...                                                  ...          ...
# 46661  \n\ntopic: Power Supply Systems and Control De...     0.134601
# 46662  \n\ntopic: Hybrid Semi-Trailer Drive Systems -...     0.011609
# 46663  \n\ntopic: Torsional Vibration Damper Technolo...     1.000000
# 46664  \n\ntopic: Automatic Transmissions for Electri...     1.000000
# 46665  \n\ntopic: Hybrid Vehicle Power Systems -  -  ...     0.032457
#
#        Representative_document
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 46661                    False
# 46662                    False
# 46663                    False
# 46664                    False
# 46665                    False
#
# [46666 rows x 8 columns]

# %%
topic_distr, _ = topic_model.approximate_distribution(abstracts)
# Out:
# 100%|██████████| 47/47 [02:06<00:00,  2.70s/it]
